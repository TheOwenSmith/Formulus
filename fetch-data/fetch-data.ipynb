# %%
import pandas as pd

# %%
df = pd.read_csv('../tick-data/data/SPY_60min.csv')

# %%
df.head()
# Out:
#              timestamp     open     high      low    close    volume
# 0  2005-01-03 08:00:00  82.6786  82.6786  82.6242  82.6446    427400
# 1  2005-01-03 09:00:00  82.6378  82.7874  82.5766  82.6242   6192600
# 2  2005-01-03 10:00:00  82.6310  82.7058  82.0666  82.1618  14895400
# 3  2005-01-03 11:00:00  82.1618  82.2026  81.9239  82.1550   5683700
# 4  2005-01-03 12:00:00  82.1550  82.1618  81.9783  82.0599   2693500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83962 entries, 0 to 83961
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  83962 non-null  object
#  1   open       83962 non-null  float64
#  2   high       83962 non-null  float64
#  3   low        83962 non-null  float64
#  4   close      83962 non-null  float64
#  5   volume     83962 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.8+ MB
